# %%
# Dependencies
import pandas as pd

# %%
file = "complete_data.csv"
data_df = pd.read_csv(file)
data_df.head()
# Out:
#           Country  Latitude  Longitude  Confirmed  Deaths  Recovered  \
# 0     Afghanistan   33.9391    67.7100       40.0     1.0        1.0
# 1         Albania   41.1533    20.1683       89.0     2.0        2.0
# 2         Algeria   28.0339     1.6596      201.0    17.0       65.0
# 3  American Samoa    0.0000     0.0000        0.0     0.0        0.0
# 4         Andorra   42.5063     1.5218      113.0     1.0        1.0
#
#             GDP  GDP Per Capita  Population  Median Age  \
# 0  2.068200e+10        531.2838    38928346        19.0
# 1  1.721000e+10       5980.2689     2877797        33.4
# 2  1.930560e+11       4402.5406    43851044        28.3
# 3  0.000000e+00          0.0000           0        26.1
# 4  2.858407e+09      36994.8441       77265        44.9
#
#    Hospital Bed Per 1000 Population Rate  Life Expectancy (years)  \
# 0                                    0.5                     52.1
# 1                                    2.9                     78.6
# ...

# %%
data_df.to_html(class: table,table-hover)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-ff4d816d7124> in <module>
# ----> 1 data_df.to_html(table-hover)
#
# NameError: name 'table' is not defined
